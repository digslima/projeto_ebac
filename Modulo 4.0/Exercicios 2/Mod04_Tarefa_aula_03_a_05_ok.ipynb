# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui

pc_mat = df_mat / 24
pc_por = df_por / 18
pc_geo = df_geo /  8
pc_ing = df_ing /  8
pc_his = df_his /  8
pc_fis = df_fis /  8
pc_qui = df_qui /  8

print("Percentual de acerto em Matemática:")
print(pc_mat)

print("Percentual de acerto em Português:")
print(pc_por)

print("Percentual de acerto em Geografia:")
print(pc_geo)

print("Percentual de acerto em Inglês:")
print(pc_ing)

print("Percentual de acerto em História:")
print(pc_his)

print("Percentual de acerto em Física:")
print(pc_fis)

print("Percentual de acerto em Química:")
print(pc_qui)
# Out:
# Percentual de acerto em Matemática:
#     Qt_acertos
# 0     0.250000
# 1     0.791667
# 2     0.583333
# 3     0.416667
# 4     0.291667
# ..         ...
# 95    0.250000
# 96    0.333333
# 97    0.958333
# 98    0.000000
# 99    0.458333
#
# [100 rows x 1 columns]
# Percentual de acerto em Português:
#     Qt_acertos
# 0     0.388889
# 1     0.555556
# 2     0.888889
# 3     0.388889
# 4     0.111111
# ..         ...
# 95    0.222222
# 96    0.055556
# 97    0.277778
# 98    0.555556
# 99    0.833333
#
# [100 rows x 1 columns]
# Percentual de acerto em Geografia:
#     Qt_acertos
# 0        0.875
# 1        0.000
# 2        0.000
# 3        0.375
# 4        0.250
# ..         ...
# 95       0.875
# 96       0.500
# 97       0.000
# 98       0.375
# 99       0.000
#
# [100 rows x 1 columns]
# Percentual de acerto em Inglês:
#     Qt_acertos
# 0        0.375
# 1        0.000
# 2        0.625
# 3        0.500
# 4        0.875
# ..         ...
# 95       0.125
# 96       0.750
# ...

# %%
# 2) Seu código aqui
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui

print("Total de acertos de cada aluno:")
print(total)
# Out:
# Total de acertos de cada aluno:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
percentual_geral = total / 90

print("Percentual geral de acerto de cada aluno:")
print(percentual_geral)
# Out:
# Percentual geral de acerto de cada aluno:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui

total_gt_45 = total[total['Qt_acertos'] > 45]
quantidade_alunos_gt_45 = len(total_gt_45)

print("Número de alunos com nota maior que 45 na segunda fase:", quantidade_alunos_gt_45)
# Out:
# Número de alunos com nota maior que 45 na segunda fase: 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
df_eliminados = total[(df_mat['Qt_acertos'] == 0) |
                      (df_fis['Qt_acertos'] == 0) |
                      (df_qui['Qt_acertos'] == 0)]

df_eliminados
# Out:
#     Qt_acertos
# 3           32
# 6           29
# 10          31
# 12          42
# 14          31
# 20          53
# 25          27
# 26          40
# 27          50
# 33          39
# 35          48
# 49          19
# 56          39
# 65          24
# 66          31
# 72          50
# 73          37
# 74          39
# 84          26
# 89          63
# 92          40
# 94          25
# 98          40

# %%
quantidade_alunos_desqualificados = len(df_eliminados)
print("Número de alunos desqualificados:", quantidade_alunos_desqualificados)
# Out:
# Número de alunos desqualificados: 23

# %%
media_hist_geo_desqualificados = df_eliminados['Qt_acertos'].mean()
print("Média em História e Geografia dos alunos desqualificados:")
print(media_hist_geo_desqualificados)
# Out:
# Média em História e Geografia dos alunos desqualificados:
# 37.17391304347826

# %%
df_aprovados = total[(df_mat['Qt_acertos'] > 0) &
                     (df_fis['Qt_acertos'] > 0) &
                     (df_qui['Qt_acertos'] > 0)]

df_aprovados
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 4           30
# 5           50
# ..         ...
# 93          56
# 95          34
# 96          27
# 97          40
# 99          42
#
# [77 rows x 1 columns]

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = '/Users/diegolima/Documents/Ciencia de Dados/Ciencia de dados/Modulo 4.0/Exercicios 2/registros de vacinacao covid ACRE.csv'

# %%
# 1) Sua solução aqui
df = pd.read_csv(arquivo, sep=';')

# %%
df.head()
# Out:
#                                  document_id  \
# 0  b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1  a1acc0b6-1cf6-4c4b-adcb-06b473a0faaf-i0b0
# 2  af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3  4879308e-5050-46bb-b8e2-11fa5646a05c-i0b0
# 4  000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1  f4e17a9e5354cb45e223d85eda02fb2f76048c801675f5...              81
# 2  6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# 3  84a341fd350c1ba7117fccbb4d2df417bc0fac0fffac37...              51
# 4  c59571e19f368d4b0cf08cd3bcabb32e5cd8baad5340f6...              65
#
#   paciente_datanascimento paciente_enumsexobiologico  paciente_racacor_codigo  \
# 0              1951-12-28                          F                        3
# 1              1939-11-22                          M                        3
# ...

# %%
# 1)
quant_vacinas = df.shape[0]
print("Quantidade de vacinas na base:", quant_vacinas)
# Out:
# Quantidade de vacinas na base: 169071

# %%
# 2)
pacientes_vacinados = df['paciente_id'].nunique()
print("Quantidade de paciente vacinados:", pacientes_vacinados)
# Out:
# Quantidade de paciente vacinados: 120517

# %%
# 3)
primeira_dose = df['vacina_descricao_dose'].unique()[0]
quant_primeira_dose = df['paciente_id'].loc[df['vacina_descricao_dose'] == primeira_dose].nunique()
print("Quantidade de paciente que receberam a primeira dose:",quant_primeira_dose)
# Out:
# Quantidade de paciente que receberam a primeira dose: 119713

# %%
# 4)
df_menor = df[df["paciente_idade"]<18]
quant_paciente_menor = df_menor['paciente_id'].nunique()
print("Quantidade de paciente vacinados menores que 18 anos:",quant_paciente_menor)
# Out:
# Quantidade de paciente vacinados menores que 18 anos: 47

# %%
# 5)
estabelecimento_vacina = df['estabelecimento_razaosocial'].nunique()
print("Quantos estabelecimentos aplicaram vacina:",estabelecimento_vacina)
# Out:
# Quantos estabelecimentos aplicaram vacina: 42

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vacinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_menor = df[df["paciente_idade"]<18].copy()
df_menor.head()
# Out:
#                                      document_id  \
# 1567   fdca313f-b348-422d-94d4-f2c66a87868c-i0b0
# 6250   b7431955-1faa-4c1e-9246-7c1e7b8bb3cb-i0b0
# 9569   fdb8d3b6-14d9-4bcc-9cfe-acd46b4a317a-i0b0
# 11338  647e2301-3ba4-463a-8d1e-2b6f38a4d99e-i0b0
# 15144  7f469e03-bece-49d0-bebc-33ad98e27f54-i0b0
#
#                                              paciente_id  paciente_idade  \
# 1567   f5e6b8c44f7c4d13a87c582def5e8d460435b02f26af8c...              17
# 6250   e1a45c07e3c393d5f0eccf4204a7ceab338f4f06696ecb...              16
# 9569   7cf3b238383a70eeb26841c01817737c9706d5b231e8c2...              17
# 11338  53eb7fed5faa26ad17ce21ee378f28e25399ab7e90bc05...              17
# 15144  dbaa6420d8a815158387668d0a59a19cf2bb63958e35d1...              16
#
#       paciente_datanascimento paciente_enumsexobiologico  \
# 1567               2003-07-18                          F
# 6250               2004-05-18                          M
# ...

# %%
# 2)
df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_datanascimento', 'paciente_enumsexobiologico',
#        'paciente_racacor_codigo', 'paciente_racacor_valor',
#        'paciente_endereco_coibgemunicipio', 'paciente_endereco_copais',
#        'paciente_endereco_nmmunicipio', 'paciente_endereco_nmpais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumnacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaosocial', 'estalecimento_nofantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoatendimento_codigo',
#        'vacina_grupoatendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataaplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
# ...

# %%
# 3)
nome_categoria=df_menor['vacina_categoria_nome'].value_counts()
print("Categoria Vacinação:")
print(nome_categoria)
# Out:
# Categoria Vacinação:
# Povos Indígenas                     33
# Trabalhadores de Saúde               9
# Povos e Comunidades Tradicionais     9
# Comorbidades                         2
# Faixa Etária                         1
# Name: vacina_categoria_nome, dtype: int64

# %%
# 4)
lista_variaveis = ['estabelecimento_valor',
       'estabelecimento_razaosocial', 'estalecimento_nofantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']
df_menor_lista = df_menor.loc[:,lista_variaveis]
print(df_menor_lista)
# Out:
#         estabelecimento_valor  \
# 1567                  2001314
# 6250                  6917291
# 9569                  6159087
# 11338                 2000040
# 15144                 7625855
# 17153                 6748759
# 18361                 6308740
# 18608                 2001748
# 20204                 6917682
# 20759                 6917291
# 21119                 6428940
# 27860                 7625855
# 29127                 6612385
# 31200                 7625855
# 35654                 6159087
# 38412                 6159087
# 51872                 2000040
# 57405                 9648968
# 61131                 6430201
# 62742                 6917291
# 66922                 7625855
# 68290                 6955525
# 69882                 5336171
# 70881                 6697151
# 75368                 6748759
# 78289                 6430201
# 79146                 2001748
# 81424                 6955525
# 84331                 2001748
# 88619                 6430201
# ...

# %%
# 5)
df_menor_lista = df_menor_lista.drop_duplicates()
df_menor_lista.shape
# Out:
# (18, 6)

# %%
estabelecimentos_unicos = df.drop_duplicates(subset='estalecimento_nofantasia')

lista_estabelecimentos = estabelecimentos_unicos.to_dict(orient='records')

lista_estabelecimentos
# Out:
# [{'document_id': 'b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0',
#   'paciente_id': '2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936c1baebad2e1c4f6633',
#   'paciente_idade': 69,
#   'paciente_datanascimento': '1951-12-28',
#   'paciente_enumsexobiologico': 'F',
#   'paciente_racacor_codigo': 3,
#   'paciente_racacor_valor': 'PARDA',
#   'paciente_endereco_coibgemunicipio': 120050.0,
#   'paciente_endereco_copais': 10.0,
#   'paciente_endereco_nmmunicipio': 'SENA MADUREIRA',
#   'paciente_endereco_nmpais': 'BRASIL',
#   'paciente_endereco_uf': 'AC',
#   'paciente_endereco_cep': 69940.0,
#   'paciente_nacionalidade_enumnacionalidade': 'B',
#   'estabelecimento_valor': 3541592,
#   'estabelecimento_razaosocial': 'PREFEITURA MUNICIPAL DE SENA MADUREIRA',
#   'estalecimento_nofantasia': 'UNIDADE BASICA DE SAUDE MARIA DAS DORES DE PAULA',
#   'estabelecimento_municipio_codigo': 120050,
#   'estabelecimento_municipio_nome': 'SENA MADUREIRA',
#   'estabelecimento_uf': 'AC',
# ...
